# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import os
import numpy as np
import sys
import matplotlib.pyplot as plt
import matplotlib 
from PIL import Image
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from captum.attr import visualization as viz
sys.path.append("../attacks/")
from utils import get_expl, torch_to_image, load_image,  convert_relu_to_softplus, heatmap_to_image
import mister_ed.loss_functions as lf
import mister_ed.utils.pytorch_utils as mister_ed_utils
from mister_ed.utils.pytorch_ssim import SSIM

# %% [markdown]
# ### load the images

# %%
normalizer = mister_ed_utils.DifferentiableNormalize(mean=[0.485, 0.456, 0.406],
                                               std=[0.229, 0.224, 0.225])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
data_mean = np.array([0.485, 0.456, 0.406])
data_std = np.array([0.229, 0.224, 0.225])

# %%
# image
img = Image.open("../sample_imagenet/sample_0.jpg")
img = torchvision.transforms.ToTensor()(
        torchvision.transforms.CenterCrop(224)(torchvision.transforms.Resize(256)(img)))
img = img.unsqueeze(0)
img = normalizer.forward(img).cuda()
# target image
target_img = Image.open("../sample_imagenet/sample_0_target.jpg")
target_img = torchvision.transforms.ToTensor()(
        torchvision.transforms.CenterCrop(224)(torchvision.transforms.Resize(256)(target_img)))
target_img = target_img.unsqueeze(0)
target_img = normalizer.forward(target_img).cuda()

# %%
##
p_img = {"add": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0}, 
         "add_stadv": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0},
         "add_recolor": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0},
         "add_stadv_recolor": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0}}
###
for i in ["add", "add_recolor", "add_stadv", "add_stadv_recolor"]:
    for j in ["saliency", "smooth_grad", "uniform_grad"]:
        for file in os.listdir("../examples/output_expl_relu/"+i+"/"+j):
            if file.startswith("x_"):
                p_img[i][j] = normalizer.forward(torch.load("../examples/output_expl_relu/"+i+"/"+j+"/"+file))

# %%
model = torchvision.models.vgg16(pretrained=True).to(device)
model = model.eval()
idx = model(img).argmax()

# %%
sigma = (torch.max(img) - torch.min(img)).item() / 5
print("sigma: ", sigma)
# Out:
# sigma:  0.9447309494018554

# %%
# original explanations
expl_saliency = get_expl(model, img, "saliency", desired_index=idx).detach().cpu()
torch.cuda.empty_cache()
expl_smooth_grad = get_expl(model, img, "saliency", desired_index=idx, smooth=True, sigma=sigma).detach().cpu()
torch.cuda.empty_cache()
expl_uniform_grad = get_expl(model, img, "uniform_grad", desired_index=idx, sigma=sigma).detach().cpu()
torch.cuda.empty_cache()

#perturbed explanations
p_expl = {"add": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0}, 
         "add_stadv": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0},
         "add_recolor": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0},
         "add_stadv_recolor": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0}}
for i, att in enumerate(["add", "add_stadv", "add_recolor", "add_stadv_recolor"]):
    for j, method in enumerate(["saliency", "smooth_grad", "uniform_grad"]):
        perturbed_img = p_img[att][method]
        if method == "smooth_grad":
            expl = get_expl(model, perturbed_img, "saliency", desired_index=idx, smooth=True, sigma=sigma)
        else:
            expl = get_expl(model, perturbed_img, method, desired_index=idx, sigma=sigma)
        p_expl[att][method] = expl.detach().cpu()
        del expl
        torch.cuda.empty_cache()
# Out:
# /home/ubuntu/captum/captum/_utils/gradient.py:59: UserWarning: Input Tensor 0 did not already require gradients, required_grads has been set automatically.
#   "required_grads has been set automatically." % index

# %% [markdown]
# ### Visualize the results

# %%
fig, ax = plt.subplots(9, 3, figsize=(9, 27))


viz.visualize_image_attr(np.transpose(expl_saliency.squeeze().numpy(), (1,2,0)),
                             np.transpose(img.squeeze().cpu().detach().numpy(), (1,2,0)),
                             method='heat_map',
                             cmap="Reds",
                             show_colorbar=False,
                             outlier_perc=2,
                             fig_size=(3,3), plt_fig_axis=(fig, ax[0, 0]), use_pyplot=False)

viz.visualize_image_attr(np.transpose(expl_smooth_grad.squeeze().numpy(), (1,2,0)),
                             np.transpose(img.squeeze().cpu().detach().numpy(), (1,2,0)),
                             method='heat_map',
                             cmap="Reds",
                             show_colorbar=False,
                             outlier_perc=2,
                             fig_size=(3,3), plt_fig_axis=(fig, ax[0, 1]), use_pyplot=False)

viz.visualize_image_attr(np.transpose(expl_uniform_grad.squeeze().numpy(), (1,2,0)),
                             np.transpose(img.squeeze().cpu().detach().numpy(), (1,2,0)),
                             method='heat_map',
                             cmap="Reds",
                             show_colorbar=False,
                             outlier_perc=2,
                             fig_size=(3,3), plt_fig_axis=(fig, ax[0, 2]), use_pyplot=False)

for i, att in enumerate(["add", "add_stadv", "add_recolor", "add_stadv_recolor"]):
    for j, method in enumerate(["saliency", "smooth_grad", "uniform_grad"]):
        perturbed_img = p_img[att][method]
        ax[2*i +1, j].imshow(torch_to_image(perturbed_img, data_mean, data_std))
        viz.visualize_image_attr(np.transpose(p_expl[att][method].squeeze().numpy(), (1,2,0)),
                             np.transpose(perturbed_img.squeeze().cpu().detach().numpy(), (1,2,0)),
                             method='heat_map',
                             cmap="Reds",
                             show_colorbar=False,
                             outlier_perc=2,
                             fig_size=(3,3), plt_fig_axis=(fig, ax[2*i + 2, j]), use_pyplot=False)
#################
for i in range(9):
    for j in range(3):
        ax[i,j].axis('off')
        ax[i,j].set_xticks([])
        ax[i,j].set_yticks([])
ax[0, 0].set_title("saliency", fontsize=12)
ax[0, 1].set_title("smooth_grad", fontsize=12)
ax[0, 2].set_title("uniform_grad", fontsize=12)
# fig.text(0.12, 0.84, 'original expls', style = 'oblique', fontsize = 10, horizontalalignment ='right')
# fig.text(0.12, 0.71, 'add', style = 'oblique', fontsize = 10, horizontalalignment ='right')
# fig.text(0.12, 0.55, 'add+stadv', style = 'oblique', fontsize = 10, horizontalalignment ='right')
# fig.text(0.12, 0.37, 'add+recolor', style = 'oblique', fontsize = 10, horizontalalignment ='right')
# fig.text(0.12, 0.2, 'add+stadv+recolor', style = 'oblique', fontsize = 10, horizontalalignment ='right')
# fig.text(0.12, 0.2, 'Softplus (saliency)', style = 'oblique', fontsize = 20, horizontalalignment ='right')
plt.subplots_adjust(wspace=0.008, hspace=0.07)
# plt.savefig("compare_attacks_viz.jpg", dpi=300, bbox_inches='tight', pad_inches=0.05);

# %% [markdown]
# ### Quantitative comparison

# %% [markdown]
# #### SSIM

# %%
ssim_similarity = SSIM()

# %%
ssim_to_original_map = {"add": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0}, 
         "add_stadv": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0},
         "add_recolor": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0},
         "add_stadv_recolor": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0}}

for att in ["add", "add_stadv", "add_recolor", "add_stadv_recolor"]:
    for method, org_map in zip(["saliency", "smooth_grad", "uniform_grad"], 
                               [expl_saliency, expl_smooth_grad, expl_uniform_grad]):
        ssim_to_original_map[att][method] = ssim_similarity.forward(org_map, p_expl[att][method])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-65800caba581> in <module>
#       7     for method, org_map in zip(["saliency", "smooth_grad", "uniform_grad"],
#       8                                [expl_saliency, expl_smooth_grad, expl_uniform_grad]):
# ----> 9         ssim_to_original_map[att][method] = ssim_similarity.forward(org_map, p_expl[att][method])
#
# ~/Robust_Explanations/attacks/mister_ed/utils/pytorch_ssim.py in forward(self, img1, img2)
#      64
#      65
# ---> 66         return _ssim(img1, img2, window, self.window_size, channel, self.size_average)
#      67
#      68 def ssim(img1, img2, window_size = 11, size_average = True):
#
# ~/Robust_Explanations/attacks/mister_ed/utils/pytorch_ssim.py in _ssim(img1, img2, window, window_size, channel, size_average)
#      20 def _ssim(img1, img2, window, window_size, channel, size_average = True):
#      21     mu1 = F.conv2d(img1, window, padding = window_size//2, groups = channel)
# ---> 22     mu2 = F.conv2d(img2, window, padding = window_size//2, groups = channel)
#      23
#      24     mu1_sq = mu1.pow(2)
#
# RuntimeError: Expected 4-dimensional input for 4-dimensional weight [3, 1, 11, 11], but got 3-dimensional input of size [1, 224, 224] instead

# %%
expl_saliency.size()
# Out:
# torch.Size([1, 224, 224])

# %%
ssim_to_original_map
# Out:
# {'add': {'saliency': tensor(0.4961),
#   'smooth_grad': tensor(0.9799),
#   'uniform_grad': tensor(0.9454)},
#  'add_stadv': {'saliency': tensor(0.5071),
#   'smooth_grad': tensor(0.9711),
#   'uniform_grad': tensor(0.9287)},
#  'add_recolor': {'saliency': tensor(0.4921),
#   'smooth_grad': tensor(0.9784),
#   'uniform_grad': tensor(0.9448)},
#  'add_stadv_recolor': {'saliency': tensor(0.5094),
#   'smooth_grad': tensor(0.9650),
#   'uniform_grad': tensor(0.9362)}}

# %% [markdown]
# #### spearman rank-order correlation

# %%
from scipy.stats import spearmanr as spr
import scipy.spatial as spatial

# %%
spr_to_original_map = {"add": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0}, 
         "add_stadv": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0},
         "add_recolor": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0},
         "add_stadv_recolor": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0}}

for att in ["add", "add_stadv", "add_recolor", "add_stadv_recolor"]:
    for method, org_map in zip(["saliency", "smooth_grad", "uniform_grad"], 
                               [expl_saliency, expl_smooth_grad, expl_uniform_grad]):
        spr_to_original_map[att][method] = spr(org_map.flatten(), p_expl[att][method].flatten())[0]

# %%
spr_to_original_map
# Out:
# {'add': {'saliency': 0.14442710671790482,
#   'smooth_grad': 0.7080902514226923,
#   'uniform_grad': 0.703683774303104},
#  'add_stadv': {'saliency': 0.15856224371494146,
#   'smooth_grad': 0.6372593413471557,
#   'uniform_grad': 0.6461709120637491},
#  'add_recolor': {'saliency': 0.141973398167918,
#   'smooth_grad': 0.682209824911487,
#   'uniform_grad': 0.6895290642088345},
#  'add_stadv_recolor': {'saliency': 0.16166186833759524,
#   'smooth_grad': 0.5943007233954998,
#   'uniform_grad': 0.6946135311707619}}

# %% [markdown]
# #### cosine distance

# %%
cosd_to_original_map = {"add": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0}, 
         "add_stadv": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0},
         "add_recolor": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0},
         "add_stadv_recolor": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0}}

for att in ["add", "add_stadv", "add_recolor", "add_stadv_recolor"]:
    for method, org_map in zip(["saliency", "smooth_grad"], 
                               [expl_saliency, expl_smooth_grad, expl_uniform_grad]):
        cosd_to_original_map[att][method] = float(spatial.distance.cosine(org_map.flatten(), 
                                                                          p_expl[att][method].flatten()))

# %%
cosd_to_original_map
# Out:
# {'add': {'saliency': 0.5418198704719543,
#   'smooth_grad': 0.1865028738975525,
#   'uniform_grad': 0},
#  'add_stadv': {'saliency': 0.5500042736530304,
#   'smooth_grad': 0.23789513111114502,
#   'uniform_grad': 0},
#  'add_recolor': {'saliency': 0.5490026473999023,
#   'smooth_grad': 0.2084464430809021,
#   'uniform_grad': 0},
#  'add_stadv_recolor': {'saliency': 0.5533338785171509,
#   'smooth_grad': 0.23411542177200317,
#   'uniform_grad': 0}}

# %% [markdown]
# #### MSE

# %%
target_map = get_expl(model, target_img, "saliency", normalize=True).detach().cpu()
torch.cuda.empty_cache()
# Out:
# /home/ubuntu/captum/captum/_utils/gradient.py:59: UserWarning: Input Tensor 0 did not already require gradients, required_grads has been set automatically.
#   "required_grads has been set automatically." % index

# %%
mse_to_target_map = {"add": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0}, 
         "add_stadv": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0},
         "add_recolor": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0},
         "add_stadv_recolor": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0}}

for att in ["add", "add_stadv", "add_recolor", "add_stadv_recolor"]:
    for method in ["saliency", "smooth_grad"]:
        mse_to_target_map[att][method] = F.mse_loss(target_map, p_expl[att][method])

# %%
mse_to_target_map
# Out:
# {'add': {'saliency': tensor(1.4573e-10),
#   'smooth_grad': tensor(5.4949e-10),
#   'uniform_grad': 0},
#  'add_stadv': {'saliency': tensor(1.7103e-10),
#   'smooth_grad': tensor(4.7909e-10),
#   'uniform_grad': 0},
#  'add_recolor': {'saliency': tensor(1.3917e-10),
#   'smooth_grad': tensor(5.2747e-10),
#   'uniform_grad': 0},
#  'add_stadv_recolor': {'saliency': tensor(1.6067e-10),
#   'smooth_grad': tensor(4.6875e-10),
#   'uniform_grad': 0}}

# %% [markdown]
# #### LPIPS similarity for images

# %%
import lpips

# %%
lpips_dist = lpips.LPIPS(net='vgg')
if torch.cuda.is_available():
    lpips_dist.cuda()
# Out:
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /home/ubuntu/PerceptualSimilarity/lpips/weights/v0.1/vgg.pth

# %%
lpips_to_original_image = {"add": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0}, 
         "add_stadv": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0},
         "add_recolor": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0},
         "add_stadv_recolor": {"saliency": 0, "smooth_grad": 0, "uniform_grad": 0}}
for att in ["add", "add_stadv", "add_recolor", "add_stadv_recolor"]:
    for method in ["saliency", "smooth_grad"]:
        lpips_to_original_image[att][method] = lpips_dist.forward(img, p_img[att][method]).item()

# %%
lpips_to_original_image
# Out:
# {'add': {'saliency': 0.19562490284442902,
#   'smooth_grad': 0.3689265549182892,
#   'uniform_grad': 0},
#  'add_stadv': {'saliency': 0.23146288096904755,
#   'smooth_grad': 0.28017714619636536,
#   'uniform_grad': 0},
#  'add_recolor': {'saliency': 0.20482181012630463,
#   'smooth_grad': 0.3941691517829895,
#   'uniform_grad': 0},
#  'add_stadv_recolor': {'saliency': 0.2562134265899658,
#   'smooth_grad': 0.3041177988052368,
#   'uniform_grad': 0}}

# %% [markdown]
# #### visual quantitative results

# %%
fig, ax = plt.subplots(1,2, figsize=(12, 6))

x_s = np.array([1,2,3,4])
ax[0].bar(x_s, 
           [mse_to_target_map["add"]["smooth_grad"], mse_to_target_map["add_recolor"]["smooth_grad"],
           mse_to_target_map["add_stadv"]["smooth_grad"], mse_to_target_map["add_stadv_recolor"]["smooth_grad"]], width=0.15, label="mse")

ax[0].set_xticks(x_s)
ax[0].set_xticklabels(["add", "add_recolor", "add_stadv", "add_stadv_recolor"])
ax[0].legend()

ax[1].bar(["add", "add_recolor", "add_stadv", "add_stadv_recolor"], 
           [lpips_to_original_image["add"]["smooth_grad"], lpips_to_original_image["add_recolor"]["smooth_grad"],
           lpips_to_original_image["add_stadv"]["smooth_grad"], lpips_to_original_image["add_stadv_recolor"]["smooth_grad"]], width=0.15)
# Out:
# <BarContainer object of 4 artists>

# %%
fig, ax = plt.subplots(2,2, figsize=(12, 12))

x_s = np.array([1,2,3,4])
ax[0,0].bar(x_s - 0.1, 
           [ssim_to_original_map["add"]["smooth_grad"], ssim_to_original_map["add_stadv"]["smooth_grad"],
           ssim_to_original_map["add_recolor"]["smooth_grad"], ssim_to_original_map["add_stadv_recolor"]["smooth_grad"]], width=0.15, label="ssim")

ax[0,0].bar(x_s + 0.1, 
           [spr_to_original_map["add"]["smooth_grad"], spr_to_original_map["add_stadv"]["smooth_grad"],
           spr_to_original_map["add_recolor"]["smooth_grad"], spr_to_original_map["add_stadv_recolor"]["smooth_grad"]], width=0.15, label="spr")
ax[0,0].set_xticks(x_s, ["add", "add_stadv", "add_recolor", "add_stadv_recolor"])
ax[0,0].legend()

ax[0,1].bar(["add", "add_stadv", "add_recolor", "add_stadv_recolor"], 
           [lpips_to_original_image["add"]["smooth_grad"], lpips_to_original_image["add_stadv"]["smooth_grad"],
           lpips_to_original_image["add_recolor"]["smooth_grad"], lpips_to_original_image["add_stadv_recolor"]["smooth_grad"]], width=0.15)
#########################################
ax[1,0].bar(x_s - 0.1, 
           [ssim_to_original_map["add"]["uniform_grad"], ssim_to_original_map["add_stadv"]["uniform_grad"],
           ssim_to_original_map["add_recolor"]["uniform_grad"], ssim_to_original_map["add_stadv_recolor"]["uniform_grad"]], width=0.15, label="ssim")
ax[1,0].bar(x_s + 0.1, 
           [spr_to_original_map["add"]["uniform_grad"], spr_to_original_map["add_stadv"]["uniform_grad"],
           spr_to_original_map["add_recolor"]["uniform_grad"], spr_to_original_map["add_stadv_recolor"]["uniform_grad"]], width=0.15, label="spr")
ax[1,0].set_xticks(x_s, ["add", "add_stadv", "add_recolor", "add_stadv_recolor"])
ax[1,0].legend()

ax[1,1].bar(["add", "add_stadv", "add_recolor", "add_stadv_recolor"], 
           [lpips_to_original_image["add"]["uniform_grad"], lpips_to_original_image["add_stadv"]["uniform_grad"],
           lpips_to_original_image["add_recolor"]["uniform_grad"], lpips_to_original_image["add_stadv_recolor"]["uniform_grad"]], width=0.15)
# Out:
# <BarContainer object of 4 artists>

# %%
F.mse_loss()

# %%
plt.bar()

# %%
expl_losses = []
with open("../examples/output_expl_relu/add/saliency/output.log", "r") as f:
    for line in f.readlines():
        if line.startswith("expl loss:"):
            expl_losses.append(float(line.strip().split(":")[1]))

# %%
expl_losses_add_stadv = []
with open("../examples/output_expl_relu/add_stadv/saliency/output.log", "r") as f:
    for line in f.readlines():
        if line.startswith("expl loss:"):
            expl_losses_add_stadv.append(float(line.strip().split(":")[1]))

# %%
expl_losses_add_recolor = []
with open("../examples/output_expl_relu/add_recolor/saliency/output.log", "r") as f:
    for line in f.readlines():
        if line.startswith("expl loss:"):
            expl_losses_add_recolor.append(float(line.strip().split(":")[1]))

# %%
expl_losses_add_stadv_recolor = []
with open("../examples/output_expl_relu/add_stadv_recolor/smooth_grad/output.log", "r") as f:
    for line in f.readlines():
        if line.startswith("expl loss:"):
            expl_losses_add_stadv_recolor.append(float(line.strip().split(":")[1]))

# %%
plt.plot(expl_losses, label="add")
plt.plot(expl_losses_add_stadv, label="add_stadv")
plt.plot(expl_losses_add_recolor, label="add_recolor")
# plt.plot(expl_losses_add_recolor, label="add_stadv_recolor")
plt.legend()
